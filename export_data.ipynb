# %%
import pandas as pd
from bs4 import BeautifulSoup
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/shua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import sys

# get file names of files in data. __file__ doesn't work in ipynb
data_dir = os.path.join(os.getcwd(), 'data')
data_files = os.listdir(data_dir)

# %%
data_files
# Out:
# ['al.csv',
#  'jpost_news.csv',
#  'sentences_df.csv',
#  'nyt.csv',
#  'jpost_conflict.csv',
#  'bbc.csv']

# %%
#import data into pandas dataframes from data folder for each file in folder
data = {}
for file in data_files:
    data[file] = pd.read_csv(os.path.join(data_dir, file))

# %%
data.keys()
# Out:
# dict_keys(['al.csv', 'jpost_news.csv', 'sentences_df.csv', 'nyt.csv', 'jpost_conflict.csv', 'bbc.csv'])

# %% [markdown]
# ### Al Jazeera

# %%
#remove all rows where in_title is null or article_text is null
data['al.csv'] = data['al.csv'].dropna(subset=['link', 'article_text'])

# %%
# join the text from article_text based off in_title
alj_joined_articles = data['al.csv'].groupby('link')['article_text'].apply(' '.join).reset_index()

# %%
alj_joined_articles
# Out:
#                                                    link  \
# 0     50,000 Gaza children require urgent treatment ...
# 1     8 Israeli soldiers killed in southern Gaza amb...
# 2     A Eurovision like no other: Israel’s war on Ga...
# 3     A House in Jerusalem holds the memories and gr...
# 4     A Jordanian flight to airdrop aid over a Gaza ...
# ...                                                 ...
# 1090  ‘We won’t stop’: The 24 hours Columbia etched ...
# 1091  ‘Why is FIFA silent?’: Outraged Palestinians c...
# 1092  ‘World cannot afford Lebanon becoming another ...
# 1093  ‘World must not turn its back’ on Gaza as Isra...
# 1094  “I voiced concern repeatedly, I was silenced”:...
#
#                                            article_text
# 0     The UN agency for Palestinian refugees (UNRWA)...
# 1     Hamas fighters killed eight Israeli soldiers t...
# 2     Stockholm, Sweden - Malmo is rarely the centre...
# 3     Palestinian film director Muayad Alayan has ba...
# 4     Amman, Jordan/sky above Gaza - A hulking milit...
# ...                                                 ...
# 1090  New York, United States — At about 10pm on Mon...
# 1091  Palestinian football players, officials and fa...
# 1092  United Nations Secretary-General Antonio Guter...
# 1093  The live page is now closed. You can continue ...
# 1094  This week, Israel took hold of the Rafah borde...
#
# [1095 rows x 2 columns]

# %%
alj_body = alj_joined_articles['article_text']

# %%
alj_body
# Out:
# 0       The UN agency for Palestinian refugees (UNRWA)...
# 1       Hamas fighters killed eight Israeli soldiers t...
# 2       Stockholm, Sweden - Malmo is rarely the centre...
# 3       Palestinian film director Muayad Alayan has ba...
# 4       Amman, Jordan/sky above Gaza - A hulking milit...
#                               ...
# 1090    New York, United States — At about 10pm on Mon...
# 1091    Palestinian football players, officials and fa...
# 1092    United Nations Secretary-General Antonio Guter...
# 1093    The live page is now closed. You can continue ...
# 1094    This week, Israel took hold of the Rafah borde...
# Name: article_text, Length: 1095, dtype: object

# %% [markdown]
# ### Jerusalem Post

# %%
data["jpost_conflict.csv"]
# Out:
#                   PublishDate  \
# 0     2024-06-23 18:22:53.147
# 1     2024-06-22 09:07:01.303
# 2     2024-06-21 10:46:41.027
# 3     2024-06-20 17:10:36.087
# 4     2024-06-20 10:07:39.147
# ...                       ...
# 1995  2020-11-22 15:29:22.203
# 1996  2020-11-22 14:31:29.173
# 1997  2020-11-22 21:17:40.527
# 1998  2020-11-22 18:57:52.497
# 1999  2020-11-21 18:24:18.253
#
#                                                   Title  \
# 0     IDF, security forces rescue gazelles and confi...
# 1     For second time this week: Local residents of ...
# 2     Armenia unilaterally recognizes Palestinian st...
# 3     Commemorating ‘Sayfo’: The untold genocide of ...
# 4     Hezbollah war alert level rising: Is the IDF r...
# ...                                                 ...
# 1995  Gaza@@@s health system days from being overwhe...
# 1996  Iran vows to crush any Israeli attempt to hit ...
# 1997  It wasn@@@t lightning silly, the rockets were ...
# 1998            Is there a new phase for Iran in Syria?
# 1999  Israel’s shortsighted UNESCO decision in focus...
#
#                                                    Body           CategoryName
# 0     <p>IDF soldiers arrested wanted individuals an...  Arab israeli conflict
# 1     <p>An Israeli citizen in his 60s who entered <...  Arab israeli conflict
# 2     <p><a href="https://www.jpost.com/opinion/arti...  Arab israeli conflict
# 3     <p>Every year on June 15, <a href="https://www...  Arab israeli conflict
# 4     <p>Amos Hochstein, the envoy and mediator of t...  Arab israeli conflict
# ...                                                 ...                    ...
# 1995  <div>GAZA - A sharp rise in coronavirus infect...  Arab israeli conflict
# 1996  Iran on Sunday vowed to defeat any <a href="ht...  Arab israeli conflict
# 1997  Two <a href="https://www.jpost.com/breaking-ne...  Arab israeli conflict
# 1998  Last week, a new round of Israeli <a href="htt...  Arab israeli conflict
# 1999  The United States and Israel officially left t...  Arab israeli conflict
#
# [2000 rows x 4 columns]

# %%
#remove all rows where Title or Body is null
jpost_body = data['jpost_conflict.csv'].dropna(subset=['Title', 'Body'])

# %%
#run beatiful soup on the body of the articles
jpost_body = jpost_body["Body"].apply(lambda x: BeautifulSoup(x, 'lxml').get_text(separator=' '))
jpost_articles = jpost_body.apply(lambda x: x.replace('\xa0', ''))
jpost_articles = pd.DataFrame(jpost_articles)
jpost_news = data['jpost_news.csv'].dropna(subset=['Title', 'Body'])

# %%
jpost_news_body = data["jpost_news.csv"].dropna(subset=['Title', 'Body'])
jpost_news_body = jpost_news_body["Body"].apply(lambda x: BeautifulSoup(x, 'lxml').get_text(separator=' '))
jpost_news_articles = jpost_news_body.apply(lambda x: x.replace('\xa0', ''))
jpost_news_articles = pd.DataFrame(jpost_news_articles)

# %%
jpost_articles = pd.concat([jpost_articles, jpost_news_articles], axis=0)

# %%
jpost_articles
# Out:
#                                                    Body
# 0     IDF soldiers arrested wanted individuals and c...
# 1     An Israeli citizen in his 60s who entered  Kal...
# 2     Armenia  unilaterally recognized Palestinian s...
# 3     Every year on June 15,  the small Aramean comm...
# 4     Amos Hochstein, the envoy and mediator of the ...
# ...                                                 ...
# 1995  Hagai Shalom, CEO of the Tiv Taam Group, and s...
# 1996  Although the  Ministerial committee  approved ...
# 1997  The Israel - Premier Tech cycling team celebra...
# 1998  A new survey by the One Million Lobby and the ...
# 1999  Twenty-five years ago, when they were both liv...
#
# [3996 rows x 1 columns]

# %%
jpost_articles = jpost_articles.iloc[:,0] #converts to series

# %%
jpost_articles
# Out:
# 0       IDF soldiers arrested wanted individuals and c...
# 1       An Israeli citizen in his 60s who entered  Kal...
# 2       Armenia  unilaterally recognized Palestinian s...
# 3       Every year on June 15,  the small Aramean comm...
# 4       Amos Hochstein, the envoy and mediator of the ...
#                               ...
# 1995    Hagai Shalom, CEO of the Tiv Taam Group, and s...
# 1996    Although the  Ministerial committee  approved ...
# 1997    The Israel - Premier Tech cycling team celebra...
# 1998    A new survey by the One Million Lobby and the ...
# 1999    Twenty-five years ago, when they were both liv...
# Name: Body, Length: 3996, dtype: object

# %% [markdown]
# ### BBC

# %%
data["bbc.csv"]
# Out:
#                                                   Title  \
# 0     Donald Trump's Middle East peace plan: The Isr...
# 1     What does Trump’s Middle East plan say on key ...
# 2     Israel attack: PM says Israel at war after 250...
# 3     Elderly Israelis beat isolation with tech lessons
# 4       Explainer: Israel, annexation and the West Bank
# ...                                                 ...
# 1204  Israel confirms deaths of four more hostages i...
# 1205  Gaza war: Dozens reported killed in Israeli st...
# 1206  Palestinian state recognised by Ireland, what ...
# 1207  Military ‘pause’ on Gaza road inflames divisio...
# 1208  Gaza: Israel's Netanyahu dissolves war cabinet...
#
#                                                    Link  \
# 0            https://www.bbc.com/news/newsbeat-51294755
# 1     https://www.bbc.com/news/world-middle-east-512...
# 2     https://www.bbc.com/news/world-middle-east-516...
# 3     https://www.bbc.com/news/blogs-news-from-elsew...
# 4     https://www.bbc.com/news/world-middle-east-527...
# ...                                                 ...
# 1204     https://www.bbc.com/news/articles/c722r0p31x7o
# 1205     https://www.bbc.com/news/articles/c722r0p31x7o
# 1206     https://www.bbc.com/news/articles/c722r0p31x7o
# 1207     https://www.bbc.com/news/articles/c2992985yk1o
# 1208     https://www.bbc.com/news/articles/ce99m0n99z0o
#
#                 Published_Date  \
# 0     2020-01-29T11:21:42.000Z
# 1     2020-01-29T17:53:26.000Z
# 2     2020-02-24T02:26:17.000Z
# 3     2020-04-06T14:20:23.000Z
# 4     2020-06-16T17:27:43.000Z
# ...                        ...
# 1204  2024-06-15T18:40:48.022Z
# 1205  2024-06-15T18:40:48.022Z
# 1206  2024-06-15T18:40:48.022Z
# 1207  2024-06-16T13:45:22.056Z
# 1208  2024-06-17T10:04:40.075Z
#
#                                                    Body Newspaper
# 0     The "deal of the century". The "last opportuni...       BBC
# 1     US President Donald Trump has unveiled his lon...       BBC
# 2     The Israeli military has carried out air strik...       BBC
# 3     Senior citizens in Israel stuck in their homes...       BBC
# 4     Israeli Prime Minister Benjamin Netanyahu says...       BBC
# ...                                                 ...       ...
# 1204  Eight Israeli soldiers were killed in a blast ...       BBC
# 1205  Eight Israeli soldiers were killed in a blast ...       BBC
# 1206  Eight Israeli soldiers were killed in a blast ...       BBC
# 1207  When is a ceasefire not a ceasefire? According...       BBC
# 1208  Israel’s Prime Minister Benjamin Netanyahu has...       BBC
#
# [1209 rows x 5 columns]

# %%
bbc= data["bbc.csv"].dropna(subset=['Title', 'Body'])
#return body where body is unique
bbc_body = bbc["Body"].drop_duplicates()

# %%
bbc_body
# Out:
# 0       The "deal of the century". The "last opportuni...
# 1       US President Donald Trump has unveiled his lon...
# 2       The Israeli military has carried out air strik...
# 3       Senior citizens in Israel stuck in their homes...
# 4       Israeli Prime Minister Benjamin Netanyahu says...
#                               ...
# 1202    The UN children's agency Unicef has told the B...
# 1203    The US has imposed sanctions on an Israeli gro...
# 1204    Eight Israeli soldiers were killed in a blast ...
# 1207    When is a ceasefire not a ceasefire? According...
# 1208    Israel’s Prime Minister Benjamin Netanyahu has...
# Name: Body, Length: 1105, dtype: object

# %% [markdown]
# ### New York Times

# %%
nyt_data = data["nyt.csv"].dropna(subset=['Title', 'Body Text'])

# %%
data["nyt.csv"][data["nyt.csv"]['Body Text'].isnull()]
# Out:
#                                                   Title  \
# 164   In House Hearing, Republicans Demand Disciplin...
# 328   Aid Group Calls Halts in Funding for UNRWA ‘Re...
# 491   Inside the Pro-Palestinian Group Protesting Ac...
# 492   U.S. Urges Israel to Do More to Spare Civilian...
# 493   How a 6-Second Video Turned a Campus Protest I...
# ...                                                 ...
# 1963  With 102 Workers Killed, U.N. Agency in Gaza S...
# 1964  Biden, Caught in Political Cross Currents, Nav...
# 1965  Israel Softened Its Demands in Cease-Fire Nego...
# 1966  Israel’s Army Is Ready to Invade Gaza. Its Div...
# 1967  House Republicans Attacked. New York’s Chancel...
#
#                                                    Link  \
# 164   https://www.nytimes.com/2024/05/23/us/house-he...
# 328   https://www.nytimes.com/2024/01/30/world/middl...
# 491   https://www.nytimes.com/2023/11/17/us/students...
# 492   https://www.nytimes.com/2023/12/18/world/middl...
# 493   https://www.nytimes.com/2023/12/18/nyregion/co...
# ...                                                 ...
# 1963  https://www.nytimes.com/2023/12/05/us/politics...
# 1964  https://www.nytimes.com/2023/10/09/world/middl...
# 1965  https://www.nytimes.com/2023/11/19/world/middl...
# 1966  https://www.nytimes.com/2023/10/07/world/middl...
# 1967  https://www.nytimes.com/2023/07/10/world/middl...
#
#                 Published_Date  \
# 164   2024-05-23T20:30:25+0000
# 328   2024-01-30T07:25:46+0000
# 491   2023-11-17T19:25:47+0000
# 492   2023-12-18T23:12:48+0000
# 493   2023-12-18T08:00:29+0000
# ...                        ...
# 1963  2023-12-05T23:36:51+0000
# 1964  2023-10-09T18:41:42+0000
# 1965  2023-11-19T10:01:14+0000
# 1966  2023-10-07T22:00:21+0000
# 1967  2023-07-10T12:48:34+0000
#
#                                                Abstract  \
# 164   Leaders of Northwestern, U.C.L.A. and Rutgers,...
# 328   The U.S. and some other donor countries said t...
# 491   Students for Justice in Palestine, which was f...
# 492   The American defense secretary reiterated “uns...
# 493   A pro-Palestinian protest at the Cooper Union ...
# ...                                                 ...
# 1963  While the president has backed Israel’s right ...
# 1964  Israel mobilized 300,000 reservists amid signs...
# 1965  Since 2006, Gershon Baskin, an Israeli peace a...
# 1966  Palestinian militants from Gaza launched an ea...
# 1967  In a first reading of a bill that would limit ...
#
#                                          Lead Paragraph Body Text  \
# 164   House Republicans used words like “violence,” ...       NaN
# 328   Aid groups working in Gaza expressed dismay at...       NaN
# 491   After last month’s attack on Israel by Hamas, ...       NaN
# 492   Top United States officials prodded Israel on ...       NaN
# 493   In the six-second video clip, pro-Palestinian ...       NaN
# ...                                                 ...       ...
# 1963  For two months, President Biden has strongly b...       NaN
# 1964  Israel ordered a “complete siege” of the Gaza ...       NaN
# 1965  For 17 years, on and off, two men maintained a...       NaN
# 1966  Israel battled on Saturday to repel one of the...       NaN
# 1967  After a three-month hiatus, Israel’s far-right...       NaN
#
#                Newspaper
# 164   The New York Times
# 328   The New York Times
# 491   The New York Times
# 492   The New York Times
# 493   The New York Times
# ...                  ...
# 1963  The New York Times
# 1964  The New York Times
# 1965  The New York Times
# 1966  The New York Times
# 1967  The New York Times
#
# [1478 rows x 7 columns]

# %%
#drop if body text contains "We are having trouble retrieving the article content"
nyt_data = nyt_data[~nyt_data['Body Text'].str.contains("We are having trouble retrieving the article content")]

# %%
nyt_data
# Out:
#                                                   Title  \
# 15    4 Israeli Soldiers Are Killed in Rafah in Appa...
# 21    Gantz quits Israel’s government in a dispute w...
# 24    U.S. Intelligence Helped Israel Rescue Four Ho...
# 28    Blinken to Visit Israel and Three Arab States ...
# 30    Israeli Hostage Rescue Fallout, and Far Right ...
# ...                                                 ...
# 470   Settler Violence Against Palestinians in the W...
# 477                    The New State of the War in Gaza
# 485   Protesters fill the streets in New York to sup...
# 488   Biden’s Rating Dips on Gaza, and Marvel Drops ...
# 1572            Some Israelis are flying home to fight.
#
#                                                    Link  \
# 15    https://www.nytimes.com/2024/06/11/world/middl...
# 21    https://www.nytimes.com/2024/06/10/world/middl...
# 24    https://www.nytimes.com/2024/06/08/world/middl...
# 28    https://www.nytimes.com/2024/06/07/world/middl...
# 30    https://www.nytimes.com/2024/06/10/podcasts/is...
# ...                                                 ...
# 470   https://www.nytimes.com/2023/10/30/world/middl...
# 477   https://www.nytimes.com/2023/12/21/podcasts/th...
# 485   https://www.nytimes.com/2023/10/28/nyregion/pa...
# 488   https://www.nytimes.com/2023/12/19/podcasts/bi...
# 1572  https://www.nytimes.com/2023/10/07/world/some-...
#
#                 Published_Date  \
# 15    2024-06-11T10:42:56+0000
# 21    2024-06-10T07:08:45+0000
# 24    2024-06-08T15:56:08+0000
# 28    2024-06-07T18:34:11+0000
# 30    2024-06-10T10:00:07+0000
# ...                        ...
# 470   2023-10-30T22:17:20+0000
# 477   2023-12-21T11:00:03+0000
# 485   2023-10-29T01:55:09+0000
# 488   2023-12-19T11:01:51+0000
# 1572  2023-10-07T23:37:03+0000
#
#                                                Abstract  \
# 15    Israel said the soldiers were killed when Hama...
# 21    The resignation exposed the divisions at the t...
# 24    Intelligence collection and analysis teams fro...
# 28    The U.S. secretary of state is expected to vis...
# 30            Plus, Apple’s Siri gets an A.I. makeover.
# ...                                                 ...
# 470   More than 100 Palestinians have been killed, m...
# 477   The accidental killing of three hostages by Is...
# 485   A large demonstration crossed the Brooklyn Bri...
# 488                      Hear the news in five minutes.
# 1572                                                NaN
#
#                                          Lead Paragraph  \
# 15    The Israeli military said Tuesday that four Is...
# 21    The Israeli politician Benny Gantz, a key memb...
# 24    The U.S. provided intelligence on the hostages...
# 28    Secretary of State Antony J. Blinken plans to ...
# 30                                  On Today’s Episode:
# ...                                                 ...
# 470   Attacks on Palestinians in the occupied West B...
# 477   After the accidental killing of three hostages...
# 485   Crowds of pro-Palestinian demonstrators packed...
# 488   The New York Times Audio app is home to journa...
# 1572  As Israelis living abroad woke up on Saturday ...
#
#                                               Body Text           Newspaper
# 15    Israel-HamasWar Advertisement Israel said the ...  The New York Times
# 21    Israel-HamasWar Advertisement Supported by The...  The New York Times
# 24    Israel-HamasWar Advertisement Intelligence col...  The New York Times
# 28    Israel-HamasWar Advertisement The U.S. secreta...  The New York Times
# 30    For more audio journalism and storytelling,dow...  The New York Times
# ...                                                 ...                 ...
# 470   Israel-HamasWar Advertisement More than 100 Pa...  The New York Times
# 477   For more audio journalism and storytelling,dow...  The New York Times
# 485   Israel-HamasWar Advertisement A large demonstr...  The New York Times
# 488   For more audio journalism and storytelling,dow...  The New York Times
# 1572  As Israelis living abroad woke up on Saturday ...  The New York Times
#
# [74 rows x 7 columns]

# %% [markdown]
# ##### There aren't that many nyt articles where the body actually exists, and even if they exist, the articles are behind a paywall. So I'm going to use the other three sources.

# %%
alj_df = alj_body.to_frame(name="article")
alj_df['source'] = 'alj'

jpost_df = jpost_articles.to_frame(name="article")
jpost_df['source'] = 'jpost'

bbc_df = bbc_body.to_frame(name="article")
bbc_df['source'] = 'bbc'

# Step 2: Combine the DataFrames into a single DataFrame
combined_df = pd.concat([alj_df, jpost_df, bbc_df], axis=0).reset_index(drop=True)

# %%
combined_df
# Out:
#                                                 article source
# 0     The UN agency for Palestinian refugees (UNRWA)...    alj
# 1     Hamas fighters killed eight Israeli soldiers t...    alj
# 2     Stockholm, Sweden - Malmo is rarely the centre...    alj
# 3     Palestinian film director Muayad Alayan has ba...    alj
# 4     Amman, Jordan/sky above Gaza - A hulking milit...    alj
# ...                                                 ...    ...
# 6191  The UN children's agency Unicef has told the B...    bbc
# 6192  The US has imposed sanctions on an Israeli gro...    bbc
# 6193  Eight Israeli soldiers were killed in a blast ...    bbc
# 6194  When is a ceasefire not a ceasefire? According...    bbc
# 6195  Israel’s Prime Minister Benjamin Netanyahu has...    bbc
#
# [6196 rows x 2 columns]

# %%
def split_into_sentences(article):
    sentences = nltk.sent_tokenize(article)
    return sentences

# Apply the function and expand the DataFrame
combined_df['sentences'] = combined_df['article'].apply(split_into_sentences)

# Now explode the sentences column to create individual rows for each sentence
expanded_df = combined_df.explode('sentences').reset_index()

# Rename the 'sentences' column to 'sentence'
expanded_df = expanded_df.rename(columns={"sentences": "sentence", "index": "original_article"})
expanded_df = expanded_df.drop(columns=['article'])
# Display the result
expanded_df.head()
# Out:
#    original_article source                                           sentence
# 0                 0    alj  The UN agency for Palestinian refugees (UNRWA)...
# 1                 0    alj  In a statement on Saturday, the agency noted “...
# 2                 0    alj  UNRWA teams work tirelessly to reach families ...
# 3                 0    alj  UNICEF spokesperson James Elder also described...
# 4                 0    alj  “More aid workers have been killed in this war...

# %%
expanded_df
# Out:
#         original_article source  \
# 0                      0    alj
# 1                      0    alj
# 2                      0    alj
# 3                      0    alj
# 4                      0    alj
# ...                  ...    ...
# 174354              6195    bbc
# 174355              6195    bbc
# 174356              6195    bbc
# 174357              6195    bbc
# 174358              6195    bbc
#
#                                                  sentence
# 0       The UN agency for Palestinian refugees (UNRWA)...
# 1       In a statement on Saturday, the agency noted “...
# 2       UNRWA teams work tirelessly to reach families ...
# 3       UNICEF spokesperson James Elder also described...
# 4       “More aid workers have been killed in this war...
# ...                                                   ...
# 174354  This is a democracy,” he told reporters.The Is...
# 174355  There have been further signs of strain in the...
# 174356  Supplies have been held back at the crossing p...
# 174357  It added that they had located weapons, struck...
# 174358  Following a recent intensification in exchange...
#
# [174359 rows x 3 columns]

# %%
#show some examples of the sentences
expanded_df['sentence'].sample(10).tolist()
# Out:
# ['The three-part plan that the president unveiled last week would see a "surge" of humanitarian aid, as well as an exchange of some hostages for Palestinian prisoners before a permanent end to the war.The proposal, however, has encountered vocal opposition from some members of Israel\'s government, which has raised doubt that an agreement might be reached.',
#  'Please God, next year we’ll be in a different time and it will be happier.” Around 100,000 people gathered at an Independence Day rally in Tel Aviv’s Hostages Square to hear speeches from survivors of October 7 as well as those with family members still being held hostage by Hamas in Gaza.',
#  'The IDF has said that while they struck dozens of Hamas targets during the operation, including weapons manufacturing plants and multi-barrel rocket launchers during the fighting, they were not able to destroy the group’s rocket arsenal.',
#  '“In recent weeks, in response to an increased number of alerts, we have carried out extensive  counter-terrorism  operations, which have curtailed both [terror] capabilities and intentions,” Gantz said, adding that “These operations will continue.” \n “We will increase our presence on the ground and we will exact a price from those who spread terror and incitement,” Gantz said.',
#  "Finally, there's my younger brother, who is in the seventh grade.",
#  'They can sell their physical labor in cities for long hours for NIS 8,000-9,000 a month, or they can work for criminal organizations.',
#  'Journalists, especially in war zones, face immense challenges in reporting conflict realities.',
#  'Many health fund members have been turned down for such services without being given any explanation and details about how to complain to appeals committees.',
#  'Of course there is a hole in this thinking.',
#  'Nearly 600 Palestinian rockets and mortars have been fired at Israel since Friday, an Israeli official said.']

# %%
expanded_df.dropna(inplace=True)
expanded_df.isna().sum()
# Out:
# original_article    0
# source              0
# sentence            0
# dtype: int64

# %%
expanded_df.to_csv('data/sentences_df.csv', index=False)

# %%
# Out:
# original_article    0
# source              0
# sentence            1
# dtype: int64
